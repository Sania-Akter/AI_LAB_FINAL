# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# -------- MODEL --------
def build_fcf_nn(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Flatten()(inputs)
    x = Dense(512, activation='relu')(x)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model


# -------- TRAIN FUNCTION --------
def run_dataset(dataset_name):
    if dataset_name == "mnist":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

    elif dataset_name == "fashion":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

    elif dataset_name == "cifar":
        (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    # Normalize
    x_train = x_train / 255.0
    x_test = x_test / 255.0

    # One-Hot
    y_train = to_categorical(y_train, 10)
    y_test = to_categorical(y_test, 10)

    model = build_fcf_nn(x_train.shape[1:], 10)

    model.fit(x_train, y_train,
              validation_split=0.1,
              epochs=10,
              batch_size=128)

    loss, acc = model.evaluate(x_test, y_test)
    print(f"{dataset_name} Test Accuracy:", acc)


# -------- MAIN --------
run_dataset("mnist")
run_dataset("fashion")
run_dataset("cifar")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8666 - loss: 0.4625 - val_accuracy: 0.9718 - val_loss: 0.1014
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9723 - loss: 0.0886 - val_accuracy: 0.9715 - val_loss: 0.0915
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9825 - loss: 0.0530 - val_accuracy: 0.9790 - val_loss: 0.0759
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9892 - loss: 0.0350 - val_accuracy: 0.9763 - val_loss: 0.0780
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9902 - loss: 0.0291 - val_accuracy: 0.9682 - val_loss: 0.1169
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9916 - loss: 0.0258 - val_accuracy: 0.9792 - val_loss: 0.0828
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9934 - loss: 0.0198 - val_accuracy: 0.9813 - val_loss: 0.0731
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.9800 - val_loss: 0.0810
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9954 - loss: 0.0151 - val_accuracy: 0.9783 - val_loss: 0.0938
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9942 - loss: 0.0188 - val_accuracy: 0.9808 - val_loss: 0.0842
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9780 - loss: 0.1068
# mnist Test Accuracy: 0.9812999963760376
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.7745 - loss: 0.6670 - val_accuracy: 0.8383 - val_loss: 0.4309
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8633 - loss: 0.3744 - val_accuracy: 0.8708 - val_loss: 0.3620
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8810 - loss: 0.3271 - val_accuracy: 0.8740 - val_loss: 0.3388
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8885 - loss: 0.3000 - val_accuracy: 0.8820 - val_loss: 0.3195
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.8976 - loss: 0.2791 - val_accuracy: 0.8742 - val_loss: 0.3534
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.8978 - loss: 0.2715 - val_accuracy: 0.8878 - val_loss: 0.3108
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9021 - loss: 0.2584 - val_accuracy: 0.8862 - val_loss: 0.3028
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9090 - loss: 0.2386 - val_accuracy: 0.8882 - val_loss: 0.3183
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9139 - loss: 0.2247 - val_accuracy: 0.8867 - val_loss: 0.3374
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9156 - loss: 0.2237 - val_accuracy: 0.8883 - val_loss: 0.3065
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8827 - loss: 0.3385
# fashion Test Accuracy: 0.8823999762535095
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# Epoch 1/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.2558 - loss: 2.0564 - val_accuracy: 0.3590 - val_loss: 1.7599
# Epoch 2/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 37ms/step - accuracy: 0.3792 - loss: 1.7243 - val_accuracy: 0.4100 - val_loss: 1.6504
# Epoch 3/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4148 - loss: 1.6292 - val_accuracy: 0.4220 - val_loss: 1.6369
# Epoch 4/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4458 - loss: 1.5454 - val_accuracy: 0.4580 - val_loss: 1.5183
# Epoch 5/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4581 - loss: 1.5142 - val_accuracy: 0.4306 - val_loss: 1.5902
# Epoch 6/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4744 - loss: 1.4630 - val_accuracy: 0.4648 - val_loss: 1.5069
# Epoch 7/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.4898 - loss: 1.4240 - val_accuracy: 0.4682 - val_loss: 1.5045
# Epoch 8/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 13s 38ms/step - accuracy: 0.4960 - loss: 1.4115 - val_accuracy: 0.4716 - val_loss: 1.4835
# Epoch 9/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.5034 - loss: 1.3847 - val_accuracy: 0.4970 - val_loss: 1.4339
# Epoch 10/10
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 39ms/step - accuracy: 0.5149 - loss: 1.3486 - val_accuracy: 0.5010 - val_loss: 1.4176
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.4983 - loss: 1.4172
# cifar Test Accuracy: 0.4936999976634979
