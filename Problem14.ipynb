# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# 1. Load Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# 2. Model Builder
def build_model(activation='relu', loss_fn='categorical_crossentropy'):
    model = models.Sequential([
        layers.Input(shape=(32,32,3)),
        layers.Conv2D(32, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Conv2D(64, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(128, activation=activation),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=loss_fn,
        metrics=['accuracy']
    )
    return model

# 3. Experiments
configs = [
    ('relu', 'categorical_crossentropy'),
    ('tanh', 'categorical_crossentropy'),
    ('relu', 'mean_squared_error'),
]

for act, loss in configs:
    print(f"\nTraining with Activation={act}, Loss={loss}")
    model = build_model(act, loss)

    if loss == 'categorical_crossentropy':
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)
    else:
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)

    test_loss, test_acc = model.evaluate(x_test, y_test_cat)
    print("Test Accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 109s 1us/step
#
# Training with Activation=relu, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.3894 - loss: 1.6885 - val_accuracy: 0.5563 - val_loss: 1.2220
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5941 - loss: 1.1574 - val_accuracy: 0.6458 - val_loss: 1.0218
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6569 - loss: 0.9858 - val_accuracy: 0.6554 - val_loss: 0.9957
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6938 - loss: 0.8820 - val_accuracy: 0.6657 - val_loss: 0.9598
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7240 - loss: 0.7909 - val_accuracy: 0.6857 - val_loss: 0.9045
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6877 - loss: 0.8972
# Test Accuracy: 0.685699999332428
#
# Training with Activation=tanh, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.4283 - loss: 1.6121 - val_accuracy: 0.6028 - val_loss: 1.1485
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6119 - loss: 1.1192 - val_accuracy: 0.6103 - val_loss: 1.1212
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6570 - loss: 0.9852 - val_accuracy: 0.6543 - val_loss: 1.0060
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7018 - loss: 0.8676 - val_accuracy: 0.6695 - val_loss: 0.9643
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7391 - loss: 0.7585 - val_accuracy: 0.6743 - val_loss: 0.9607
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6775 - loss: 0.9581
# Test Accuracy: 0.6743000149726868
#
# Training with Activation=relu, Loss=mean_squared_error
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.3769 - loss: 0.0746 - val_accuracy: 0.5567 - val_loss: 0.0578
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5901 - loss: 0.0543 - val_accuracy: 0.6243 - val_loss: 0.0502
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6444 - loss: 0.0481 - val_accuracy: 0.6496 - val_loss: 0.0472
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6827 - loss: 0.0437 - val_accuracy: 0.6558 - val_loss: 0.0467
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7107 - loss: 0.0402 - val_accuracy: 0.6790 - val_loss: 0.0438
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6807 - loss: 0.0439
# Test Accuracy: 0.6790000200271606
